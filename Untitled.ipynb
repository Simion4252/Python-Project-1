# %% [markdown]
# ## 1. Python

# %% [markdown]
# ## 1.1 Introduction to algorithms

# %% [markdown]
# Think about problem, algorithm , them problem

# %%
x=int(input("Enter the first number: "))
print(x)
y=int(input("Enter the second number: "))
print(y)
sum=x+y
print(x,"+",y, "=", sum)

# %%
a=int(input("Enter the first number: "))
y=b=int(input("Enter the second number: "))
if a>=b:
    return a
else:
    return b
print("The maximum is", max(a,b))

# %%
def maximum(a,b):
    if a>=b:
    return (f'The maximum of {a} and {b} is {a})
else:
    return b(f'The maximum of {a} and {b} is {b})

# %%
for i in range(5):
     my_list = []
my_list.append(i)
